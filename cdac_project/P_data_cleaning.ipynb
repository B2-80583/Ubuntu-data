# %%
import pandas as pd

# %%
df = pd.read_csv("flipkart_laptop_data.csv")

df
# Out:
#                                                Product      Price  Rating  \
# 0    Wings Nuvobook S1 Aluminium Alloy Metal Body I...    ₹24,990     4.2
# 1    Wings Nuvobook S1 Aluminium Alloy Metal Body I...    ₹24,990     4.2
# 2    MSI Katana 15 Core i7 13th Gen 13620H - (16 GB...  ₹1,13,990     3.3
# 3    Acer Predator Neo (2023) Core i7 13th Gen 1370...  ₹1,04,990     4.5
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  ₹1,17,990     4.7
# ..                                                 ...        ...     ...
# 738  Wings Nuvobook S2 Aluminium Alloy Metal Body I...    ₹26,990     4.2
# 739  ASUS ROG Flow X13 with RTX 3080 eGPU Ryzen 9 O...  ₹1,54,990     3.6
# 740  DELL Core i3 11th Gen - (8 GB/256 GB SSD/Windo...    ₹38,990     3.8
# 741  Wings Nuvobook V1 Aluminium Alloy Metal Body I...    ₹29,990     4.3
# 742  Wings Nuvobook V1 Aluminium Alloy Metal Body I...    ₹29,990     4.3
#
#                                            Description  \
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2    Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# 3    Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# 4    Apple M2 Processor8 GB Unified Memory RAMMac O...
# ..                                                 ...
# 738  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 739  AMD Ryzen 9 Octa Core Processor32 GB LPDDR4X R...
# 740  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 741  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 742  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
#
#                                                    Url  Product Review ID
# 0    /wings-nuvobook-s1-aluminium-alloy-metal-body-...                  1
# 1    /wings-nuvobook-s1-aluminium-alloy-metal-body-...                  1
# 2    /msi-katana-15-core-i7-13th-gen-13620h-16-gb-1...                  1
# 3    /acer-predator-neo-2023-core-i7-13th-gen-13700...                  1
# 4    /apple-2022-macbook-air-m2-8-gb-512-gb-ssd-mac...                  1
# ..                                                 ...                ...
# 738  /wings-nuvobook-s2-aluminium-alloy-metal-body-...                 38
# 739  /asus-rog-flow-x13-rtx-3080-egpu-ryzen-9-octa-...                 38
# 740  /dell-core-i3-11th-gen-8-gb-256-gb-ssd-windows...                 38
# 741  /wings-nuvobook-v1-aluminium-alloy-metal-body-...                 38
# 742  /wings-nuvobook-v1-aluminium-alloy-metal-body-...                 38
#
# [743 rows x 6 columns]

# %%
#Check number of uniqueIds to see if there's any duplicate record in our dataset
df['Product'].nunique()
# Out:
# 442

# %%
df['Price'] = df['Price'].str.replace('₹', '')
df['Price'] = df['Price'].str.replace(',', '')
df['Price'] = df['Price'].astype(float)

# %%
# Construct the product-review links from product links
review_urls = []
df['Url'] = 'https://www.flipkart.com' + df['Url']
for link in df['Url']:
    url = link.split('/p/')
    review_link = url[0] + '/product-reviews/' + url[1]
    review_urls.append(review_link)

# %%
df
# Out:
#                                                Product     Price  Rating  \
# 0    Wings Nuvobook S1 Aluminium Alloy Metal Body I...   24990.0     4.2
# 1    Wings Nuvobook S1 Aluminium Alloy Metal Body I...   24990.0     4.2
# 2    MSI Katana 15 Core i7 13th Gen 13620H - (16 GB...  113990.0     3.3
# 3    Acer Predator Neo (2023) Core i7 13th Gen 1370...  104990.0     4.5
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  117990.0     4.7
# ..                                                 ...       ...     ...
# 738  Wings Nuvobook S2 Aluminium Alloy Metal Body I...   26990.0     4.2
# 739  ASUS ROG Flow X13 with RTX 3080 eGPU Ryzen 9 O...  154990.0     3.6
# 740  DELL Core i3 11th Gen - (8 GB/256 GB SSD/Windo...   38990.0     3.8
# 741  Wings Nuvobook V1 Aluminium Alloy Metal Body I...   29990.0     4.3
# 742  Wings Nuvobook V1 Aluminium Alloy Metal Body I...   29990.0     4.3
#
#                                            Description  \
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2    Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# 3    Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# 4    Apple M2 Processor8 GB Unified Memory RAMMac O...
# ..                                                 ...
# 738  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 739  AMD Ryzen 9 Octa Core Processor32 GB LPDDR4X R...
# 740  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 741  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 742  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
#
#                                                    Url  Product Review ID
# 0    https://www.flipkart.com/wings-nuvobook-s1-alu...                  1
# 1    https://www.flipkart.com/wings-nuvobook-s1-alu...                  1
# 2    https://www.flipkart.com/msi-katana-15-core-i7...                  1
# 3    https://www.flipkart.com/acer-predator-neo-202...                  1
# 4    https://www.flipkart.com/apple-2022-macbook-ai...                  1
# ..                                                 ...                ...
# 738  https://www.flipkart.com/wings-nuvobook-s2-alu...                 38
# 739  https://www.flipkart.com/asus-rog-flow-x13-rtx...                 38
# 740  https://www.flipkart.com/dell-core-i3-11th-gen...                 38
# 741  https://www.flipkart.com/wings-nuvobook-v1-alu...                 38
# 742  https://www.flipkart.com/wings-nuvobook-v1-alu...                 38
#
# [743 rows x 6 columns]

# %%
# Store the list as column in the DataFrame
df['Review Url'] = review_urls

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product            743 non-null    object
#  1   Price              743 non-null    float64
#  2   Rating             743 non-null    float64
#  3   Description        743 non-null    object
#  4   Url                743 non-null    object
#  5   Product Review ID  743 non-null    int64
#  6   Review Url         743 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.8+ KB
# None

# %%
df.describe()
# Out:
#                Price      Rating  Product Review ID
# count     743.000000  743.000000         743.000000
# mean    60420.133244    4.222880          17.873486
# std     36146.037901    0.318713          10.861546
# min     20489.000000    2.500000           1.000000
# 25%     31150.000000    4.100000           8.000000
# 50%     51990.000000    4.200000          17.000000
# 75%     83245.000000    4.400000          27.000000
# max    309490.000000    5.000000          38.000000
